# %%
import pandas as pd
data = pd.read_csv('./data3/20191126_VCMS_Metadata_Export.txt', sep="|")
data.head(5)
# Out:
#   video_houseid video_seriesid video_seasonid  \
# 0     TTL603365            NaN            NaN
# 1     TTL609937         228SER      501467S02
# 2     AEO223997            NaN            NaN
# 3     HBO218010          21SER      501022S06
# 4     HBO220781          43SER      501090S04
#
#                             video_concatenated_title  \
# 0                                      #FollowFriday
# 1  Series/A-Z:Comedy:High Maintenance Series:Seas...
# 2                                            #POPFAN
# 3  Series/A-Z:Drama:TRUE BLOOD Series:Season 6:Ep...
# 4  Series/A-Z:Drama:TREME Series:Season 4:Ep 5:.....
#
#                     reverse_video_concatenated_title              video_title  \
# 0                                      #FollowFriday            #FollowFriday
# 1  #goalz:Ep 9:Season 2:High Maintenance Series:C...                   #goalz
# 2                                            #POPFAN                  #POPFAN
# ...

# %%
list(data.columns)
# Out:
# ['video_houseid',
#  'video_seriesid',
#  'video_seasonid',
#  'video_concatenated_title',
#  'reverse_video_concatenated_title',
#  'video_title',
#  'video_category',
#  'video_genre',
#  'video_season_number',
#  'video_episode_number',
#  'video_series_name',
#  'video_production_year',
#  'video_duration',
#  'video_rating_la',
#  'video_rating_br',
#  'video_rating_ca',
#  'video_synopsis',
#  'video_directors',
#  'video_actors',
#  'video_offer_start_br',
#  'video_offer_end_br',
#  'video_offer_start_la',
#  'video_offer_end_la',
#  'video_offer_start_ca',
#  'video_offer_end_ca']

# %% [markdown]
# # Coverage Rate

# %%
100 * data.count() / data.shape[0]
# Out:
# video_houseid                        99.945370
# video_seriesid                       56.378039
# video_seasonid                       56.569243
# video_concatenated_title            100.000000
# reverse_video_concatenated_title    100.000000
# video_title                          99.918055
# video_category                      100.000000
# video_genre                          99.986343
# video_season_number                  99.931713
# video_episode_number                 99.931713
# video_series_name                    55.736138
# video_production_year                99.931713
# video_duration                       99.931713
# video_rating_la                      99.931713
# video_rating_br                      99.931713
# video_rating_ca                      99.931713
# video_synopsis                       94.810161
# video_directors                      87.257580
# video_actors                         85.714286
# video_offer_start_br                 99.863425
# ...
